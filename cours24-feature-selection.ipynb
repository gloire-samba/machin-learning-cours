# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import VarianceThreshold
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest, chi2, SelectFromModel, RFE, RFECV
from sklearn.linear_model import SGDClassifier

# %%
iris = load_iris()
x = iris.data
y = iris.target

plt.plot(x)
plt.legend(iris.feature_names)

# %%
x.var(axis=0)
# Out:
# array([0.68112222, 0.18871289, 3.09550267, 0.57713289])

# %%
selector = VarianceThreshold(threshold=0.2)
selector.fit_transform(x)
# Out:
# array([[5.1, 1.4, 0.2],
#        [4.9, 1.4, 0.2],
#        [4.7, 1.3, 0.2],
#        [4.6, 1.5, 0.2],
#        [5. , 1.4, 0.2],
#        [5.4, 1.7, 0.4],
#        [4.6, 1.4, 0.3],
#        [5. , 1.5, 0.2],
#        [4.4, 1.4, 0.2],
#        [4.9, 1.5, 0.1],
#        [5.4, 1.5, 0.2],
#        [4.8, 1.6, 0.2],
#        [4.8, 1.4, 0.1],
#        [4.3, 1.1, 0.1],
#        [5.8, 1.2, 0.2],
#        [5.7, 1.5, 0.4],
#        [5.4, 1.3, 0.4],
#        [5.1, 1.4, 0.3],
#        [5.7, 1.7, 0.3],
#        [5.1, 1.5, 0.3],
#        [5.4, 1.7, 0.2],
#        [5.1, 1.5, 0.4],
#        [4.6, 1. , 0.2],
#        [5.1, 1.7, 0.5],
#        [4.8, 1.9, 0.2],
#        [5. , 1.6, 0.2],
#        [5. , 1.6, 0.4],
#        [5.2, 1.5, 0.2],
#        [5.2, 1.4, 0.2],
#        [4.7, 1.6, 0.2],
#        [4.8, 1.6, 0.2],
#        [5.4, 1.5, 0.4],
#        [5.2, 1.5, 0.1],
#        [5.5, 1.4, 0.2],
#        [4.9, 1.5, 0.2],
#        [5. , 1.2, 0.2],
#        [5.5, 1.3, 0.2],
#        [4.9, 1.4, 0.1],
# ...

# %%
selector.get_support()
# Out:
# array([ True, False,  True,  True])

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
np.array(iris.feature_names)
# Out:
# array(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'], dtype='<U17')

# %%
np.array(iris.feature_names)[selector.get_support()]
# Out:
# array(['sepal length (cm)', 'petal length (cm)', 'petal width (cm)'],
#       dtype='<U17')

# %%
chi2(x, y)
# Out:
# (array([ 10.81782088,   3.7107283 , 116.31261309,  67.0483602 ]),
#  array([4.47651499e-03, 1.56395980e-01, 5.53397228e-26, 2.75824965e-15]))

# %%
selector = SelectKBest(chi2, k=1)
selector.fit_transform(x,y)
# Out:
# array([[1.4],
#        [1.4],
#        [1.3],
#        [1.5],
#        [1.4],
#        [1.7],
#        [1.4],
#        [1.5],
#        [1.4],
#        [1.5],
#        [1.5],
#        [1.6],
#        [1.4],
#        [1.1],
#        [1.2],
#        [1.5],
#        [1.3],
#        [1.4],
#        [1.7],
#        [1.5],
#        [1.7],
#        [1.5],
#        [1. ],
#        [1.7],
#        [1.9],
#        [1.6],
#        [1.6],
#        [1.5],
#        [1.4],
#        [1.6],
#        [1.6],
#        [1.5],
#        [1.5],
#        [1.4],
#        [1.5],
#        [1.2],
#        [1.3],
#        [1.4],
#        [1.3],
#        [1.5],
#        [1.3],
#        [1.3],
#        [1.3],
#        [1.6],
#        [1.9],
#        [1.4],
#        [1.6],
#        [1.4],
#        [1.5],
#        [1.4],
#        [4.7],
#        [4.5],
#        [4.9],
#        [4. ],
#        [4.6],
#        [4.5],
#        [4.7],
#        [3.3],
#        [4.6],
#        [3.9],
#        [3.5],
#        [4.2],
# ...

# %%
selector.get_support()
# Out:
# array([False, False,  True, False])

# %%
selector = SelectKBest(chi2, k=2)
selector.fit_transform(x,y)
selector.get_support()
# Out:
# array([False, False,  True,  True])

# %%
selector = SelectFromModel(SGDClassifier(random_state=0),threshold= "mean")
selector.fit_transform(x,y)
# Out:
# array([[1.4, 0.2],
#        [1.4, 0.2],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.7, 0.4],
#        [1.4, 0.3],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.5, 0.1],
#        [1.5, 0.2],
#        [1.6, 0.2],
#        [1.4, 0.1],
#        [1.1, 0.1],
#        [1.2, 0.2],
#        [1.5, 0.4],
#        [1.3, 0.4],
#        [1.4, 0.3],
#        [1.7, 0.3],
#        [1.5, 0.3],
#        [1.7, 0.2],
#        [1.5, 0.4],
#        [1. , 0.2],
#        [1.7, 0.5],
#        [1.9, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.4],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.2],
#        [1.5, 0.4],
#        [1.5, 0.1],
#        [1.4, 0.2],
#        [1.5, 0.2],
#        [1.2, 0.2],
#        [1.3, 0.2],
#        [1.4, 0.1],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.3, 0.3],
#        [1.3, 0.3],
#        [1.3, 0.2],
#        [1.6, 0.6],
#        [1.9, 0.4],
#        [1.4, 0.3],
#        [1.6, 0.2],
# ...

# %%
selector.get_support()
# Out:
# array([False, False,  True,  True])

# %%
selector.estimator_
# Out:
# SGDClassifier(random_state=0)

# %%
selector.estimator_.coef_
# Out:
# array([[  8.64029104,  27.2851296 , -40.01819009, -17.73533424],
#        [ -5.48888269, -58.79616709,  22.88584985, -54.14457159],
#        [-81.28026953, -75.17372078, 130.76437145, 131.39608339]])

# %%
selector.estimator_.coef_.shape
# Out:
# (3, 4)

# %%
selector.estimator_.coef_.mean(axis=0)
# Out:
# array([-26.04295373, -35.56158609,  37.87734374,  19.83872585])

# %%
selector.estimator_.coef_.mean(axis=0).mean()
# Out:
# np.float64(-0.9721175565229512)

# %%
selector.get_support()
# Out:
# array([False, False,  True,  True])

# %%
selector = RFECV(estimator=SGDClassifier(random_state=0),step=1,min_features_to_select=2,cv=5)
selector.fit_transform(x,y)
selector.ranking_
# Out:
# array([2, 1, 1, 1])
