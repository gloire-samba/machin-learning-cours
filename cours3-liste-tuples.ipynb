# %%
liste_1 = [1, 2, 4, 5,35,84]
villes = ["Paris", "Berlin", "Londres", "Bruxelles"]
liste_2 = [liste_1, villes]  # liste de listes
liste3_=[]

# %%
tuple_1=(1,2,6,1,7)

# %%
prenom = "gloire"

# %%
#Indexing
print(villes[0])
print(villes[1])
print(villes[-1]) #dernier element
print(villes[-2]) #avant dernier element
# Out:
# Paris
# Berlin
# Bruxelles
# Londres

# %%
#slicing
print(villes[:3])
print(villes[2:])
print(villes[1:3])
print(villes[::2]) #elements d'indice pair
print(villes[::-1]) #inverse de la liste
print(prenom[::-1]) #inverse de la chaine de caractere
print(prenom[:3])
# Out:
# ['Paris', 'Berlin', 'Londres']
# ['Londres', 'Bruxelles']
# ['Berlin', 'Londres']
# ['Paris', 'Londres']
# ['Bruxelles', 'Londres', 'Berlin', 'Paris']
# eriolg
# glo

# %%
villes[0] = "Marseille"
print(villes)
# Out:
# ['Marseille', 'Berlin', 'Londres', 'Bruxelles']

# %%
villes.append("Dublin") 

print(villes)
# Out:
# ['Marseille', 'Berlin', 'Londres', 'Bruxelles', 'Dublin']

# %%
villes.insert(2, "Madrid")
print(villes)
# Out:
# ['Marseille', 'Berlin', 'Madrid', 'Londres', 'Bruxelles', 'Dublin']

# %%
villes_2 = ["Amsterdam", "Rome"]

villes.extend(villes_2)
print(villes)
# Out:
# ['Marseille', 'Berlin', 'Madrid', 'Londres', 'Bruxelles', 'Dublin', 'Amsterdam', 'Rome']

# %%
print(len(villes))
# Out:
# 8

# %%
villes.sort()

print(villes)
# Out:
# ['Amsterdam', 'Berlin', 'Bruxelles', 'Dublin', 'Londres', 'Madrid', 'Marseille', 'Rome']

# %%
villes.sort(reverse=True)   
print(villes)
# Out:
# ['Rome', 'Marseille', 'Madrid', 'Londres', 'Dublin', 'Bruxelles', 'Berlin', 'Amsterdam']

# %%
liste_2 = [52,51,23,61,3,2,78,24]
liste_2.sort()
print(liste_2)
# Out:
# [2, 3, 23, 24, 51, 52, 61, 78]

# %%
print(villes.count("Londres")) #nombre d'occurrences de "Londres" dans la liste villes
# Out:
# 1

# %%
if "Londres" in villes:
    print("Londres est dans la liste des villes")
else:
    print("Londres n'est pas dans la liste des villes")
# Out:
# Londres est dans la liste des villes

# %%
if "Paris" in villes:
    print("Paris est dans la liste des villes")
else:
    print("Paris n'est pas dans la liste des villes")
# Out:
# Paris n'est pas dans la liste des villes

# %%
for i in villes:
    print(i)
# Out:
# Rome
# Marseille
# Madrid
# Londres
# Dublin
# Bruxelles
# Berlin
# Amsterdam

# %%
for index, valeur in enumerate(villes):
    print(index, valeur)
# Out:
# 0 Rome
# 1 Marseille
# 2 Madrid
# 3 Londres
# 4 Dublin
# 5 Bruxelles
# 6 Berlin
# 7 Amsterdam

# %%
for a, b in zip(villes, liste_2):
    print(a, b)
# Out:
# Rome 2
# Marseille 3
# Madrid 23
# Londres 24
# Dublin 51
# Bruxelles 52
# Berlin 61
# Amsterdam 78
