# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bitcoin = pd.read_csv("BTC-EUR.csv",index_col="Date",parse_dates=True)
ethereum = pd.read_csv("ETH-EUR.csv",index_col="Date",parse_dates=True)

# %%
bitcoin.head()
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2011-10-04  3.700  3.821  3.746  3.750      3.750    1357
# 2011-10-05  3.750  3.820  3.650  3.676      3.676    3349
# 2011-10-06  3.676  3.743  3.450  3.550      3.550    6642
# 2011-10-07  3.550  3.590  2.900  3.293      3.293    7135
# 2011-10-08  3.293  3.283  2.872  2.890      2.890    2007

# %%
bitcoin["Close"].plot(figsize=(9,6))
plt.show()

# %%
bitcoin.index
# Out:
# DatetimeIndex(['2011-10-04', '2011-10-05', '2011-10-06', '2011-10-07',
#                '2011-10-08', '2011-10-09', '2011-10-10', '2011-10-11',
#                '2011-10-12', '2011-10-13',
#                ...
#                '2019-09-25', '2019-09-26', '2019-09-27', '2019-09-28',
#                '2019-09-29', '2019-09-30', '2019-10-01', '2019-10-02',
#                '2019-10-03', '2019-10-04'],
#               dtype='datetime64[ns]', name='Date', length=2923, freq=None)

# %%
bitcoin.loc["2019", "Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bitcoin.loc["2019-09", "Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bitcoin.loc["2017":"2019", "Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bitcoin.loc["2019", "Close"].resample("M").mean().plot(figsize=(9,6))
plt.show()
# Out:
# /tmp/ipykernel_223079/2389093628.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   bitcoin.loc["2019", "Close"].resample("M").mean().plot(figsize=(9,6))

# %%
bitcoin.loc["2019", "Close"].resample("W").mean().plot(figsize=(9,6))
plt.show()

# %%
bitcoin.loc["2019", "Close"].resample("2W").mean().plot(figsize=(9,6))
plt.show()

# %%
plt.figure(figsize=(12,8))
bitcoin.loc["2019","Close"].plot()
bitcoin.loc["2019","Close"].resample("M").mean().plot(label = "moyenne mensuelle", lw = 3, ls = ":", alpha = 0.8)
bitcoin.loc["2019","Close"].resample("W").mean().plot(label = "moyenne hebdomadaire", lw = 3, ls = "--", alpha = 0.8)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_223079/3264507319.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   bitcoin.loc["2019","Close"].resample("M").mean().plot(label = "moyenne mensuelle", lw = 3, ls = ":", alpha = 0.8)

# %%
bitcoin.loc["2019", "Close"].resample("W").agg(["mean", "std","min","max"])
# Out:
#                     mean         std           min           max
# Date
# 2019-01-06   3413.619995   86.412199   3345.330078   3565.800049
# 2019-01-13   3308.722830  187.370818   3090.370117   3513.979980
# 2019-01-20   3193.085728   42.170285   3129.989990   3263.669922
# 2019-01-27   3139.568534   20.884335   3110.709961   3171.270020
# 2019-02-03   3010.647182   21.591732   2986.850098   3054.060059
# 2019-02-10   3093.135742  125.474356   2973.739990   3247.080078
# 2019-02-17   3196.895717   21.848029   3171.590088   3238.939941
# 2019-02-24   3472.014334  100.274323   3311.520020   3648.610107
# 2019-03-03   3361.397147   13.607572   3343.159912   3378.629883
# 2019-03-10   3427.681432   71.614973   3285.050049   3503.760010
# 2019-03-17   3460.784319   49.759121   3410.310059   3536.739990
# 2019-03-24   3531.442906   12.569157   3510.860107   3543.360107
# 2019-03-31   3584.785749   79.031293   3468.629883   3657.600098
# 2019-04-07   4359.692906  303.865513   3702.659912   4638.450195
# 2019-04-14   4590.292829   95.803144   4492.450195   4727.270020
# 2019-04-21   4660.011510   97.034134   4467.560059   4744.200195
# 2019-04-28   4758.075753  121.620704   4636.649902   4943.890137
# 2019-05-05   4914.774344  216.621558   4632.700195   5179.490234
# 2019-05-12   5612.528599  492.788225   5104.229980   6348.859863
# 2019-05-19   6992.334263  317.247631   6545.189941   7346.979980
# 2019-05-26   7195.460031  291.802864   6851.439941   7798.850098
# 2019-06-02   7734.090053  140.978623   7455.419922   7848.850098
# 2019-06-09   6983.092773  154.624071   6797.279785   7246.609863
# 2019-06-16   7477.018555  405.206911   7004.439941   8007.589844
# 2019-06-23   8714.534180  563.699683   8112.049805   9503.870117
# 2019-06-30  10267.635603  649.981645   9484.490234  11240.339844
# 2019-07-07   9935.128627  410.435962   9368.700195  10614.639648
# 2019-07-14  10392.299805  718.835346   9073.389648  11225.849609
# 2019-07-21   9229.286970  493.431924   8406.070313   9647.250000
# 2019-07-28   8812.220145  230.264062   8524.440430   9227.419922
# 2019-08-04   9239.845703  525.189637   8528.809570   9873.959961
# 2019-08-11  10440.625697  239.002636  10083.360352  10722.349609
# 2019-08-18   9434.581473  386.063629   8999.950195  10159.049805
# 2019-08-25   9337.704241  314.075617   9096.250000   9853.820313
# 2019-09-01   8894.015764  268.715989   8580.379883   9337.750000
# 2019-09-08   9518.921596  112.282309   9342.450195   9685.990234
# 2019-09-15   9309.785715   91.611734   9149.929688   9432.070313
# 2019-09-22   9213.828543   94.554136   9068.450195   9334.099609
# 2019-09-29   7728.245745  506.474254   7375.950195   8823.660156
# 2019-10-06   7582.142676   74.938380   7487.083496   7655.250000

# %%
m = bitcoin.loc["2019", "Close"].resample("W").agg(["mean", "std","min","max"])

plt.figure(figsize=(12,8))
m["mean"]["2019"].plot(label = "moyenne hebdomadaire")
plt.fill_between(m.index, m["min"], m["max"], label = "min max par semaine",alpha = 0.2)

plt.legend()
plt.show()

# %%
bitcoin.loc["2019", "Close"].rolling(window =7).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(12,8))
bitcoin.loc["2019", "Close"].plot()
bitcoin.loc["2019", "Close"].rolling(window =7).mean().plot(label ="cnetre", lw = 3, ls = ":", alpha = 0.8)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
bitcoin.loc["2019-09", "Close"].plot()
bitcoin.loc["2019-09", "Close"].rolling(window =7).mean().plot(label ="cnetre", lw = 3, ls = ":", alpha = 0.8)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
bitcoin.loc["2019-09", "Close"].plot()
bitcoin.loc["2019-09", "Close"].rolling(window =7).mean().plot(label ="moving average", lw = 3, ls = ":", alpha = 0.8)
bitcoin.loc["2019-09", "Close"].rolling(window =7,center = True).mean().plot(label ="moving average", lw = 3, ls = ":", alpha = 0.8)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
bitcoin.loc["2019-09", "Close"].plot()
bitcoin.loc["2019-09", "Close"].rolling(window =7).mean().plot(label ="moving average", lw = 3, ls = ":", alpha = 0.8)
bitcoin.loc["2019-09", "Close"].rolling(window =7,center = True).mean().plot(label ="moving average", lw = 3, ls = ":", alpha = 0.8)
bitcoin.loc["2019-09", "Close"].ewm(alpha = 0.6).mean().plot(label ="ewm", lw = 3, ls = ":", alpha = 0.8)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
bitcoin.loc["2019-09", "Close"].plot()
for i in np.arange(0.2, 1, 0.2):
    bitcoin.loc["2019-09", "Close"].ewm(alpha = i).mean().plot(label = f"ewm{i}", lw = 3, ls = ":", alpha = 0.8)
plt.legend()
plt.show()

# %%
ethereum.head()
# Out:
#              Open    High     Low  Close  Adj Close  Volume
# Date
# 2015-08-07  0.593  20.000  0.5930   2.56       2.56   15200
# 2015-08-08  2.560   2.598  0.5616   0.65       0.65   32816
# 2015-08-09  0.650   0.800  0.5235   0.70       0.70    4041
# 2015-08-10  0.700   0.750  0.5850   0.68       0.68    5645
# 2015-08-11  0.680   1.008  0.5915   0.95       0.95   21607

# %%
ethereum.loc["2019", "Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
pd.merge(bitcoin, ethereum, on = "Date",how = "inner", suffixes=("_btc","_eth"))
# Out:
#                Open_btc     High_btc      Low_btc    Close_btc  Adj Close_btc  \
# Date
# 2015-08-07   255.710007   258.880005   253.639999   256.250000     256.250000
# 2015-08-08   256.250000   257.029999   239.279999   240.199997     240.199997
# 2015-08-09   240.199997   246.110001   239.039993   243.910004     243.910004
# 2015-08-10   243.910004   248.039993   240.779999   241.679993     241.679993
# 2015-08-11   241.679993   247.190002   240.399994   245.759995     245.759995
# ...                 ...          ...          ...          ...            ...
# 2019-09-29  7523.009766  7541.020020  7247.169922  7375.950195    7375.950195
# 2019-09-30  7375.950195  7667.890137  7075.589844  7626.029785    7626.029785
# 2019-10-01  7626.029785  7818.279785  7535.799805  7625.560059    7625.560059
# 2019-10-02  7625.560059  7663.270020  7489.770020  7655.250000    7655.250000
# 2019-10-03  7655.250000  7685.930176  7379.220215  7516.790039    7516.790039
#
#             Volume_btc    Open_eth    High_eth     Low_eth   Close_eth  \
# Date
# 2015-08-07     1446808    0.593000   20.000000    0.593000    2.560000
# 2015-08-08     1426996    2.560000    2.598000    0.561600    0.650000
# 2015-08-09      797790    0.650000    0.800000    0.523500    0.700000
# 2015-08-10     1135445    0.700000    0.750000    0.585000    0.680000
# 2015-08-11     1472221    0.680000    1.008000    0.591500    0.950000
# ...                ...         ...         ...         ...         ...
# 2019-09-29    39755968  159.130005  159.779999  150.610001  155.160004
# 2019-09-30   101457908  155.160004  166.649994  151.229996  165.910004
# 2019-10-01    75644316  165.910004  170.710007  159.330002  161.410004
# 2019-10-02    51871334  161.410004  165.740005  159.699997  165.240005
# 2019-10-03    49437308  165.240005  165.520004  154.960007  159.690002
#
#             Adj Close_eth  Volume_eth
# Date
# 2015-08-07       2.560000       15200
# 2015-08-08       0.650000       32816
# 2015-08-09       0.700000        4041
# 2015-08-10       0.680000        5645
# 2015-08-11       0.950000       21607
# ...                   ...         ...
# 2019-09-29     155.160004     7857348
# 2019-09-30     165.910004    15659055
# 2019-10-01     161.410004    11427525
# 2019-10-02     165.240005     5760811
# 2019-10-03     159.690002     7711746
#
# [1519 rows x 12 columns]

# %%
pd.merge(bitcoin, ethereum, on = "Date",how = "outer", suffixes=("_btc","_eth"))
# Out:
#                Open_btc     High_btc      Low_btc    Close_btc  Adj Close_btc  \
# Date
# 2011-10-04     3.700000     3.821000     3.746000     3.750000       3.750000
# 2011-10-05     3.750000     3.820000     3.650000     3.676000       3.676000
# 2011-10-06     3.676000     3.743000     3.450000     3.550000       3.550000
# 2011-10-07     3.550000     3.590000     2.900000     3.293000       3.293000
# 2011-10-08     3.293000     3.283000     2.872000     2.890000       2.890000
# ...                 ...          ...          ...          ...            ...
# 2019-10-01  7626.029785  7818.279785  7535.799805  7625.560059    7625.560059
# 2019-10-02  7625.560059  7663.270020  7489.770020  7655.250000    7655.250000
# 2019-10-03  7655.250000  7685.930176  7379.220215  7516.790039    7516.790039
# 2019-10-04  7514.477051  7512.555176  7424.196289  7487.083496    7487.083496
# 2019-10-07          NaN          NaN          NaN          NaN            NaN
#
#               Volume_btc    Open_eth    High_eth     Low_eth   Close_eth  \
# Date
# 2011-10-04  1.357000e+03         NaN         NaN         NaN         NaN
# 2011-10-05  3.349000e+03         NaN         NaN         NaN         NaN
# 2011-10-06  6.642000e+03         NaN         NaN         NaN         NaN
# 2011-10-07  7.135000e+03         NaN         NaN         NaN         NaN
# 2011-10-08  2.007000e+03         NaN         NaN         NaN         NaN
# ...                  ...         ...         ...         ...         ...
# 2019-10-01  7.564432e+07  165.910004  170.710007  159.330002  161.410004
# 2019-10-02  5.187133e+07  161.410004  165.740005  159.699997  165.240005
# 2019-10-03  4.943731e+07  165.240005  165.520004  154.960007  159.690002
# 2019-10-04  1.221204e+10         NaN         NaN         NaN         NaN
# 2019-10-07           NaN  155.179993  166.309998  153.889999  164.929993
#
#             Adj Close_eth  Volume_eth
# Date
# 2011-10-04            NaN         NaN
# 2011-10-05            NaN         NaN
# 2011-10-06            NaN         NaN
# 2011-10-07            NaN         NaN
# 2011-10-08            NaN         NaN
# ...                   ...         ...
# 2019-10-01     161.410004  11427525.0
# 2019-10-02     165.240005   5760811.0
# 2019-10-03     159.690002   7711746.0
# 2019-10-04            NaN         NaN
# 2019-10-07     164.929993  10220110.0
#
# [2924 rows x 12 columns]

# %%
btc_eth = pd.merge(bitcoin, ethereum, on = "Date",how = "inner", suffixes=("_btc","_eth"))

# %%
btc_eth[["Close_btc", "Close_eth"]].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
btc_eth[["Close_btc", "Close_eth"]].plot(subplots=True, figsize=(12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
btc_eth[["Close_btc", "Close_eth"]].corr()
# Out:
#            Close_btc  Close_eth
# Close_btc   1.000000   0.791416
# Close_eth   0.791416   1.000000

# %%
correlation = btc_eth.loc["2019-09", ["Close_btc", "Close_eth"]].corr()

sns.heatmap(correlation)
# Out:
# <Axes: >

# %%
bitcoin.loc["2019", "Close"].diff().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bitcoin.loc["2019-06": "2019-07", "Close"].diff().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data = bitcoin.copy() 
data["Buy"] = np.zeros(len(data)) 
data["Sell"] = np.zeros(len(data)) 
data["RollingMax"] = data["Close"].shift(1).rolling(window=28).max() 
data["RollingMin"] = data["Close"].shift(1).rolling(window=28).min() 
data.loc[data["RollingMax"] > data["Close"], "Buy"] = 1 
data.loc[data["RollingMin"] < data["Close"], "Sell"] = -1 
data[["RollingMax", "RollingMin", "Buy", "Sell"]]
# Out:
#              RollingMax   RollingMin  Buy  Sell
# Date
# 2011-10-04          NaN          NaN  0.0   0.0
# 2011-10-05          NaN          NaN  0.0   0.0
# 2011-10-06          NaN          NaN  0.0   0.0
# 2011-10-07          NaN          NaN  0.0   0.0
# 2011-10-08          NaN          NaN  0.0   0.0
# ...                 ...          ...  ...   ...
# 2019-09-30  9685.990234  7375.950195  1.0  -1.0
# 2019-10-01  9685.990234  7375.950195  1.0  -1.0
# 2019-10-02  9590.730469  7375.950195  1.0  -1.0
# 2019-10-03  9590.730469  7375.950195  1.0  -1.0
# 2019-10-04  9493.339844  7375.950195  1.0  -1.0
#
# [2923 rows x 4 columns]

# %%
data[["RollingMax", "RollingMin", "Buy", "Sell"]].plot(subplots=True,figsize=(12,8))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)
